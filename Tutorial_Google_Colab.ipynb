# %% [markdown]
# # Diffusion-NILM

# %% [markdown]
# ## Install Requirements

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/Colab\ Notebooks/TESI/Diffusion-NILM
# !ls
# Out:
# /content/drive/MyDrive/Colab Notebooks/TESI/Diffusion-NILM
# Config	Data  engine  main.py  Models  requirements.txt  Tutorial_Google_Colab.ipynb  Utils

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.2/152.2 kB 6.5 MB/s eta 0:00:00
# ...
# WARNING: The candidate selected for download or install is a yanked version: 'mujoco' candidate (version 2.3.4 at https://files.pythonhosted.org/packages/02/7c/b784c3c3eca5f0744fd481c9d76f646fa9b8d064930118c36238e8b9e5fd/mujoco-2.3.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from https://pypi.org/simple/mujoco/) (requires-python:>=3.7))
# Reason for being yanked: Broken OBJ and PNG asset loading
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 107.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 114.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 66.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Train
#
# Parameters:
#
#
# *   name: dataset name
# *   config_file: filename of the config
# *   gpu: gpu id to use
# *   train: train flag
#
#
# Before starting the training, update the configuration file to set the appropriate number of epochs/timesteps and adjust all necessary model parameters. Additionally, in Utils/Data_utils/uk_dale_utils.py, modify the appliance names and specify the house indices you want to include.

# %%
# !python main.py --name ukdale --config_file Config/ukdale.yaml --gpu 0 --train
# Out:
# Global seed set to 2502
# {'overall': {'trainable': '934.66K', 'non_trainable': '0', 'total': '934.66K'}, 'model': {'trainable': '934.66K', 'non_trainable': '0', 'total': '934.66K'}}
# ukdale: start training...
# loss: 0.001682: 100% 60000/60000 [2:04:36<00:00,  8.03it/s]
# training complete
# Training done, time: 7476.24

# %% [markdown]
# ## Sampling
#
# Parameters:
#
# - name: dataset name
# - config_file: filename of the config
# - gpu: gpu id to use
# - milestone: number of the checkpoint to load

# %%
# !python main.py --name ukdale --config_file Config/ukdale.yaml --gpu 0 --milestone 10
# Out:
# Global seed set to 2502
# {'overall': {'trainable': '934.66K', 'non_trainable': '0', 'total': '934.66K'}, 'model': {'trainable': '934.66K', 'non_trainable': '0', 'total': '934.66K'}}
# Begin to sample...
# sampling loop time step: 100% 100/100 [00:05<00:00, 18.21it/s]
# sampling loop time step: 100% 100/100 [00:04<00:00, 23.07it/s]
# sampling loop time step: 100% 100/100 [00:04<00:00, 22.98it/s]
# sampling loop time step: 100% 100/100 [00:04<00:00, 23.37it/s]
# sampling loop time step: 100% 100/100 [00:04<00:00, 23.25it/s]
# sampling loop time step: 100% 100/100 [00:04<00:00, 23.38it/s]
# sampling loop time step: 100% 100/100 [00:04<00:00, 23.23it/s]
# sampling loop time step: 100% 100/100 [00:04<00:00, 23.31it/s]
# sampling loop time step: 100% 100/100 [00:04<00:00, 23.18it/s]
# sampling loop time step: 100% 100/100 [00:04<00:00, 22.77it/s]
# sampling loop time step: 100% 100/100 [00:04<00:00, 23.23it/s]
# sampling loop time step: 100% 100/100 [00:04<00:00, 23.24it/s]
# ...

# %% [markdown]
# ## Check MAE

# %%
# !python -c 'from Utils.Data_utils.uk_dale_utils import check_metrics; check_metrics()'
# Out:
# (26994, 256, 1) (26994, 256, 1)
# MAE: 3.979808121792809
